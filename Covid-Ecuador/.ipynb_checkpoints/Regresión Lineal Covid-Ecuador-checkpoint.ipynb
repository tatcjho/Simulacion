# %% [markdown]
# # Regresión Lineal COVID-19 Ecuador
# Realizado por: Tatiana Cárdenas Jho

# %%
#Problema:
#Generar un modelo de regresión de los casos confirmados de COVID dentro del Ecuador el mismo que permitirá predecir el comportamiento y/o predicción de la pandemia 

#Importación de librerías
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime,timedelta
import datetime as dt
from sklearn.linear_model import LinearRegression  
print('Importadas')
# Out:
# Importadas

# %%
#Carga de datos

#Variables
#dataset = pd.read_csv('dataset.csv')
#print(dataset.head())

df = pd.read_csv('dataset.csv')
print(df.shape)
df.head()
# Out:
# (407, 59)
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ECU  South America  Ecuador  2020-03-01            6          6
# 1      ECU  South America  Ecuador  2020-03-02            6          0
# 2      ECU  South America  Ecuador  2020-03-03            7          1
# 3      ECU  South America  Ecuador  2020-03-04           10          3
# 4      ECU  South America  Ecuador  2020-03-05           13          3
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.describe().round(3)
# Out:
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# count      407.000    407.000             402.000       394.000     394.000
# mean    137704.005    852.130             849.336      9215.898      43.891
# std     100545.657    967.507             468.354      5646.413     196.902
# min          6.000  -7953.000            -525.000         2.000       0.000
# 25%      44440.000    353.000             562.572      4172.750      12.000
# 50%     126419.000    765.000             869.143     11276.000      27.000
# 75%     212012.000   1202.000            1123.750     14059.000      43.000
# max     346817.000  11536.000            2038.429     17293.000    3852.000
#
#        new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# count              402.000                  407.000                407.000
# mean                42.604                 7804.996                 48.298
# ...

# %%
df.keys()
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
#Analizamos el tipo de dato que tiene el dataset en caso de que tengamos que convertir algún valor
df.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                                int64
# new_cases                                  int64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# ...

# %%
#Convertimos a la fecha en un numero para el procesamiento de regresion lineal
df['date'] = pd.to_datetime(df['date'])   
df['date'] = (df['date'] - df['date'].min())  / np.timedelta64(1,'D')
print(df['date'])
# Out:
# 0        0.0
# 1        1.0
# 2        2.0
# 3        3.0
# 4        4.0
#        ...
# 402    402.0
# 403    403.0
# 404    404.0
# 405    405.0
# 406    406.0
# Name: date, Length: 407, dtype: float64

# %%
#Seleccionamos solo las columnas con las que vammos a predecir
X = df['date'].values.reshape(-1,1)
y = df['total_cases'].values.reshape(-1,1)

# %%
#Modelo de prediccion
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
date_predicted = linear_regressor.predict(X)
# Out:
# LinearRegression()

# %%
print("Model linear Score : ",model.score(X_test,y_test))
# Out:
# Model linear Score :  0.9879289083764765

# %%
# Coeficientes obtenidos,
#Tangente:
print('Coefficients: \n', linear_regressor.coef_)
# Valor donde corta el eje Y (en X=0):
print('Independent term: \n', linear_regressor.intercept_)
# Out:
# Coefficients:
#  [[848.29342989]]
# Independent term:
#  [-34499.5613528]

# %% [markdown]
# Pruebas:

# %%
# Numero de casos que hay en la fecha actual 25/04/2021,
# según nuestro modelo, hacemos:
y_prediccion = date_predicted[[400]]
print("Prediccion para la fecha 24/04/2021:")
print(int(y_prediccion))
# Out:
# Prediccion para la fecha 24/04/2021:
# 50329

# %% [markdown]
# Gráfica:

# %%
#Graficamos
plt.scatter(X_train, y_train,  color='black')
plt.plot(X_train, model.predict(X_train), color='blue', linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#Vamos a comprobar:
# Quiero predecir cuántos "Casos" hay en la fecha actual 11/08/2021,
# según nuestro modelo, hacemos:
y_prediccion = model.predict([[600]])
print("Prediccion para la fecha 24/05/2021:")
print(int(y_prediccion))
# Out:
# Prediccion para la fecha 24/05/2021:
# 595
